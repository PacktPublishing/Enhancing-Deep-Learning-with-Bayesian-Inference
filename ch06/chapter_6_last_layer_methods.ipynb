# %%
from tensorflow.keras import Model, Sequential, layers, optimizers, metrics, losses
import tensorflow as tf
import tensorflow_probability as tfp
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
import pandas as pd
import numpy as np

# %%
seed = 213
np.random.seed(seed)
tf.random.set_seed(seed)
dtype = tf.float32

# %%
# load data and labels
boston = load_boston()
data = boston.data
targets = boston.target

# divide into train and test splits
X_train, X_test, y_train, y_test = train_test_split(data, targets, test_size=0.2)

# Scale our inputs
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
#     Alternative datasets include the California housing dataset (i.e.
#     :func:`~sklearn.datasets.fetch_california_housing`) and the Ames housing
#     dataset. You can load the datasets as follows::
#
#         from sklearn.datasets import fetch_california_housing
#         housing = fetch_california_housing()
#
#     for the California housing dataset and::
#
#         from sklearn.datasets import fetch_openml
#         housing = fetch_openml(name="house_prices", as_frame=True)
#
#     for the Ames housing dataset.
#
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# Build and train neural network which we will use as basis function

# %%
# construct our model
model = Sequential()
model.add(layers.Dense(20, input_dim=13, activation='relu', name='layer_1'))
model.add(layers.Dense(8, activation='relu', name='layer_2'))
model.add(layers.Dense(1, activation='relu', name='layer_3'))

# %%
# compile the model
model.compile(optimizer=optimizers.Adam(),
              loss=losses.MeanSquaredError(),
              metrics=[metrics.RootMeanSquaredError()],)

# %%
# train the model for 200 epochs
num_epochs = 200
model.fit(X_train, y_train, epochs=num_epochs)
mse, rmse = model.evaluate(X_test, y_test)
# Out:
# Epoch 1/200
# 13/13 [==============================] - 1s 3ms/step - loss: 605.8174 - root_mean_squared_error: 24.6134
# Epoch 2/200
# 13/13 [==============================] - 0s 2ms/step - loss: 604.8334 - root_mean_squared_error: 24.5934
# Epoch 3/200
# 13/13 [==============================] - 0s 3ms/step - loss: 602.2981 - root_mean_squared_error: 24.5418
# Epoch 4/200
# 13/13 [==============================] - 0s 3ms/step - loss: 594.6363 - root_mean_squared_error: 24.3852
# Epoch 5/200
# 13/13 [==============================] - 0s 3ms/step - loss: 577.7584 - root_mean_squared_error: 24.0366
# Epoch 6/200
# 13/13 [==============================] - 0s 3ms/step - loss: 556.3505 - root_mean_squared_error: 23.5871
# Epoch 7/200
# 13/13 [==============================] - 0s 3ms/step - loss: 532.8649 - root_mean_squared_error: 23.0839
# Epoch 8/200
# 13/13 [==============================] - 0s 4ms/step - loss: 506.4110 - root_mean_squared_error: 22.5036
# Epoch 9/200
# 13/13 [==============================] - 0s 3ms/step - loss: 476.5880 - root_mean_squared_error: 21.8309
# Epoch 10/200
# 13/13 [==============================] - 0s 3ms/step - loss: 443.7062 - root_mean_squared_error: 21.0643
# Epoch 11/200
# 13/13 [==============================] - 0s 3ms/step - loss: 405.4540 - root_mean_squared_error: 20.1359
# Epoch 12/200
# 13/13 [==============================] - 0s 3ms/step - loss: 365.2338 - root_mean_squared_error: 19.1111
# Epoch 13/200
# 13/13 [==============================] - 0s 3ms/step - loss: 322.5443 - root_mean_squared_error: 17.9595
# Epoch 14/200
# 13/13 [==============================] - 0s 3ms/step - loss: 278.3900 - root_mean_squared_error: 16.6850
# Epoch 15/200
# 13/13 [==============================] - 0s 3ms/step - loss: 235.4259 - root_mean_squared_error: 15.3436
# Epoch 16/200
# 13/13 [==============================] - 0s 3ms/step - loss: 195.1167 - root_mean_squared_error: 13.9684
# Epoch 17/200
# 13/13 [==============================] - 0s 2ms/step - loss: 159.3575 - root_mean_squared_error: 12.6237
# Epoch 18/200
# 13/13 [==============================] - 0s 2ms/step - loss: 130.7411 - root_mean_squared_error: 11.4342
200
# 13/13 [==============================] - 0s 2ms/step - loss: 12.9168 - root_mean_squared_error: 3.5940
# Epoch 97/200
# 13/13 [==============================] - 0s 2ms/step - loss: 12.8768 - root_mean_squared_error: 3.5884
# Epoch 98/200
# 13/13 [==============================] - 0s 2ms/step - loss: 12.7822 - root_mean_squared_error: 3.5752
# Epoch 99/200
# 13/13 [==============================] - 0s 3ms/step - loss: 12.7489 - root_mean_squared_error: 3.5706
# Epoch 100/200
# 13/13 [==============================] - 0s 2ms/step - loss: 12.6874 - root_mean_squared_error: 3.5619
# Epoch 101/200
# 13/13 [==============================] - 0s 2ms/step - loss: 12.6178 - root_mean_squared_error: 3.5522
# Epoch 102/200
# 13/13 [==============================] - 0s 2ms/step - loss: 12.6018 - root_mean_squared_error: 3.5499
# Epoch 103/200
# 13/13 [==============================] - 0s 3ms/step - loss: 12.5291 - root_mean_squared_error: 3.5396
# Epoch 104/200
# 13/13 [==============================] - 0s 2ms/step - loss: 12.5160 - root_mean_squared_error: 3.5378
# Epoch 105/200
# 13/13 [==============================] - 0s 2ms/step - loss: 12.4772 - root_mean_squared_error: 3.5323
# Epoch 106/200
# 13/13 [==============================] - 0s 2ms/step - loss: 12.4368 - root_mean_squared_error: 3.5266
# Epoch 107/200
# 13/13 [==============================] - 0s 2ms/step - loss: 12.3550 - root_mean_squared_error: 3.5150
# Epoch 108/200
# 13/13 [==============================] - 0s 2ms/step - loss: 12.3120 - root_mean_squared_error: 3.5089
# Epoch 109/200
# 13/13 [==============================] - 0s 2ms/step - loss: 12.2637 - root_mean_squared_error: 3.5020
# Epoch 110/200
# 13/13 [==============================] - 0s 2ms/step - loss: 12.2970 - root_mean_squared_error: 3.5067
# Epoch 111/200
# 13/13 [==============================] - 0s 2ms/step - loss: 12.1556 - root_mean_squared_error: 3.4865
# Epoch 112/200
# 13/13 [==============================] - 0s 2ms/step - loss: 12.1832 - root_mean_squared_error: 3.4904
# Epoch 113/200
# 13/13 [==============================] - 0s 2ms/step - loss: 12.1599 - root_mean_squared_error: 3.4871
# Epoch 114/200
# 13/13 [==============================] - 0s 2ms/step - loss: 12.0943 - root_mean_squared_error: 3.4777
# Epoch 115/200
# 13/13 [==============================] - 0s 2ms/step - loss: 12.0845 - root_mean_squared_error: 3.4763
# Epoch 116/200
# 13/13 [==============================] - 0s 2ms/step - loss: 12.0425 - root_mean_squared_error: 3.4702
# Epoch 117/200
# 13/13 [==============================] - 0s 2ms/step - loss: 11.9713 - root_mean_squared_error: 3.4600
# Epoch 118/200
# 13/13 [==============================] - 0s 2ms/step - loss: 11.9583 - root_mean_squared_error: 3.4581
# Epoch 119/200
# 13/13 [==============================] - 0s 2ms/step - loss: 11.9030 - root_mean_squared_error: 3.4501
# Epoch 120/200
# 13/13 [==============================] - 0s 2ms/step - loss: 12.0537 - root_mean_squared_error: 3.4718
# Epoch 121/200
# 13/13 [==============================] - 0s 2ms/step - loss: 11.8501 - root_mean_squared_error: 3.4424
# Epoch 122/200
# 13/13 [==============================] - 0s 2ms/step - loss: 11.8122 - root_mean_squared_error: 3.4369
# Epoch 123/200
# 13/13 [==============================] - 0s 2ms/step - loss: 11.7536 - root_mean_squared_error: 3.4284
# Epoch 124/200
# 13/13 [==============================] - 0s 2ms/step - loss: 11.7284 - root_mean_squared_error: 3.4247
# Epoch 125/200
# 13/13 [==============================] - 0s 2ms/step - loss: 11.6847 - root_mean_squared_error: 3.4183
# Epoch 126/200
# 13/13 [==============================] - 0s 2ms/step - loss: 11.6298 - root_mean_squared_error: 3.4103
# Epoch 127/200
# 13/13 [==============================] - 0s 2ms/step - loss: 11.5881 - root_mean_squared_error: 3.4041
# Epoch 128/200
# 13/13 [==============================] - 0s 2ms/step - loss: 11.6151 - root_mean_squared_error: 3.4081
# Epoch 129/200
# 13/13 [==============================] - 0s 2ms/step - loss: 11.5457 - root_mean_squared_error: 3.3979
# Epoch 130/200
# 13/13 [==============================] - 0s 2ms/step - loss: 11.6081 - root_mean_squared_error: 3.4071
# Epoch 131/200
# 13/13 [==============================] - 0s 2ms/step - loss: 11.7036 - root_mean_squared_error: 3.4210
# Epoch 132/200
# 13/13 [==============================] - 0s 2ms/step - loss: 11.4488 - root_mean_squared_error: 3.3836
# Epoch 133/200
# 13/13 [==============================] - 0s 2ms/step - loss: 11.4205 - root_mean_squared_error: 3.3794
# Epoch 134/200
# 13/13 [==============================] - 0s 2ms/step - loss: 11.4134 - root_mean_squared_error: 3.3784
# Epoch 135/200
# 13/13 [==============================] - 0s 2ms/step - loss: 11.3387 - root_mean_squared_error: 3.3673
# Epoch 136/200
# 13/13 [==============================] - 0s 2ms/step - loss: 11.3154 - root_mean_squared_error: 3.3638
# Epoch 137/200
# 13/13 [==============================] - 0s 2ms/step - loss: 11.3231 - root_mean_squared_error: 3.3650
# Epoch 138/200
# 13/13 [==============================] - 0s 2ms/step - loss: 11.2458 - root_mean_squared_error: 3.3535
# Epoch 139/200
# 13/13 [==============================] - 0s 2ms/step - loss: 11.2292 - root_mean_squared_error: 3.3510
# Epoch 140/200
# 13/13 [==============================] - 0s 2ms/step - loss: 11.2144 - root_mean_squared_error: 3.3488
# Epoch 141/200
# 13/13 [==============================] - 0s 2ms/step - loss: 11.1666 - root_mean_squared_error: 3.3416
# Epoch 142/200
# 13/13 [==============================] - 0s 2ms/step - loss: 11.1447 - root_mean_squared_error: 3.3384
# Epoch 143/200
# 13/13 [==============================] - 0s 2ms/step - loss: 11.0956 - root_mean_squared_error: 3.3310
# Epoch 144/200
# 13/13 [==============================] - 0s 2ms/step - loss: 11.0924 - root_mean_squared_error: 3.3305
# Epoch 145/200
# 13/13 [==============================] - 0s 2ms/step - loss: 11.0061 - root_mean_squared_error: 3.3175
# Epoch 146/200
# 13/13 [==============================] - 0s 2ms/step - loss: 11.0546 - root_mean_squared_error: 3.3248
# Epoch 147/200
# 13/13 [==============================] - 0s 2ms/step - loss: 10.9923 - root_mean_squared_error: 3.3155
# Epoch 148/200
# 13/13 [==============================] - 0s 2ms/step - loss: 10.9729 - root_mean_squared_error: 3.3125
# Epoch 149/200
# 13/13 [==============================] - 0s 2ms/step - loss: 10.9141 - root_mean_squared_error: 3.3037
# Epoch 150/200
# 13/13 [==============================] - 0s 2ms/step - loss: 10.9080 - root_mean_squared_error: 3.3027
# Epoch 151/200
# 13/13 [==============================] - 0s 2ms/step - loss: 10.9032 - root_mean_squared_error: 3.3020
# Epoch 152/200
# 13/13 [==============================] - 0s 2ms/step - loss: 10.8003 - root_mean_squared_error: 3.2864
# Epoch 153/200
# 13/13 [==============================] - 0s 2ms/step - loss: 10.8361 - root_mean_squared_error: 3.2918
# Epoch 154/200
# 13/13 [==============================] - 0s 2ms/step - loss: 10.7419 - root_mean_squared_error: 3.2775
# Epoch 155/200
# 13/13 [==============================] - 0s 2ms/step - loss: 10.7401 - root_mean_squared_error: 3.2772
# Epoch 156/200
# 13/13 [==============================] - 0s 2ms/step - loss: 10.6929 - root_mean_squared_error: 3.2700
# Epoch 157/200
# 13/13 [==============================] - 0s 2ms/step - loss: 10.6736 - root_mean_squared_error: 3.2670
# Epoch 158/200
# 13/13 [==============================] - 0s 3ms/step - loss: 10.6755 - root_mean_squared_error: 3.2673
# Epoch 159/200
# 13/13 [==============================] - 0s 2ms/step - loss: 10.6410 - root_mean_squared_error: 3.2621
# Epoch 160/200
# 13/13 [==============================] - 0s 2ms/step - loss: 10.5992 - root_mean_squared_error: 3.2556
# Epoch 161/200
# 13/13 [==============================] - 0s 2ms/step - loss: 10.5697 - root_mean_squared_error: 3.2511
# Epoch 162/200
# 13/13 [==============================] - 0s 2ms/step - loss: 10.5520 - root_mean_squared_error: 3.2484
# Epoch 163/200
# 13/13 [==============================] - 0s 2ms/step - loss: 10.4984 - root_mean_squared_error: 3.2401
# Epoch 164/200
# 13/13 [==============================] - 0s 2ms/step - loss: 10.4634 - root_mean_squared_error: 3.2347
# Epoch 165/200
# 13/13 [==============================] - 0s 2ms/step - loss: 10.4405 - root_mean_squared_error: 3.2312
# Epoch 166/200
# 13/13 [==============================] - 0s 3ms/step - loss: 10.4408 - root_mean_squared_error: 3.2312
# Epoch 167/200
# 13/13 [==============================] - 0s 2ms/step - loss: 10.3968 - root_mean_squared_error: 3.2244
# Epoch 168/200
# 13/13 [==============================] - 0s 2ms/step - loss: 10.4191 - root_mean_squared_error: 3.2279
# Epoch 169/200
# 13/13 [==============================] - 0s 2ms/step - loss: 10.3313 - root_mean_squared_error: 3.2142
# Epoch 170/200
# 13/13 [==============================] - 0s 2ms/step - loss: 10.3628 - root_mean_squared_error: 3.2191
# Epoch 171/200
# 13/13 [==============================] - 0s 2ms/step - loss: 10.2869 - root_mean_squared_error: 3.2073
# Epoch 172/200
# 13/13 [==============================] - 0s 2ms/step - loss: 10.2795 - root_mean_squared_error: 3.2062
# Epoch 173/200
# 13/13 [==============================] - 0s 2ms/step - loss: 10.2528 - root_mean_squared_error: 3.2020
# Epoch 174/200
# 13/13 [==============================] - 0s 2ms/step - loss: 10.2123 - root_mean_squared_error: 3.1957
# Epoch 175/200
# 13/13 [==============================] - 0s 2ms/step - loss: 10.1850 - root_mean_squared_error: 3.1914
# Epoch 176/200
# 13/13 [==============================] - 0s 2ms/step - loss: 10.1952 - root_mean_squared_error: 3.1930
# Epoch 177/200
# 13/13 [==============================] - 0s 2ms/step - loss: 10.3822 - root_mean_squared_error: 3.2221
# Epoch 178/200
# 13/13 [==============================] - 0s 2ms/step - loss: 10.1772 - root_mean_squared_error: 3.1902
# Epoch 179/200
# 13/13 [==============================] - 0s 2ms/step - loss: 10.1063 - root_mean_squared_error: 3.1790
# Epoch 180/200
# 13/13 [==============================] - 0s 2ms/step - loss: 10.0515 - root_mean_squared_error: 3.1704
# Epoch 181/200
# 13/13 [==============================] - 0s 2ms/step - loss: 10.0270 - root_mean_squared_error: 3.1666
# Epoch 182/200
# 13/13 [==============================] - 0s 2ms/step - loss: 10.0309 - root_mean_squared_error: 3.1672
# Epoch 183/200
# 13/13 [==============================] - 0s 2ms/step - loss: 9.9977 - root_mean_squared_error: 3.1619
# Epoch 184/200
# 13/13 [==============================] - 0s 2ms/step - loss: 9.9591 - root_mean_squared_error: 3.1558
# Epoch 185/200
# 13/13 [==============================] - 0s 2ms/step - loss: 9.9603 - root_mean_squared_error: 3.1560
# Epoch 186/200
# 13/13 [==============================] - 0s 3ms/step - loss: 9.8959 - root_mean_squared_error: 3.1458
# Epoch 187/200
# 13/13 [==============================] - 0s 2ms/step - loss: 9.8981 - root_mean_squared_error: 3.1461
# Epoch 188/200
# 13/13 [==============================] - 0s 2ms/step - loss: 9.8398 - root_mean_squared_error: 3.1368
# Epoch 189/200
# 13/13 [==============================] - 0s 2ms/step - loss: 9.8543 - root_mean_squared_error: 3.1392
# Epoch 190/200
# 13/13 [==============================] - 0s 2ms/step - loss: 9.8001 - root_mean_squared_error: 3.1305
# Epoch 191/200
# 13/13 [==============================] - 0s 2ms/step - loss: 9.7958 - root_mean_squared_error: 3.1298
# Epoch 192/200
# 13/13 [==============================] - 0s 2ms/step - loss: 9.7902 - root_mean_squared_error: 3.1289
# Epoch 193/200
# 13/13 [==============================] - 0s 2ms/step - loss: 9.7321 - root_mean_squared_error: 3.1196
# Epoch 194/200
# 13/13 [==============================] - 0s 2ms/step - loss: 9.7404 - root_mean_squared_error: 3.1210
# Epoch 195/200
# 13/13 [==============================] - 0s 2ms/step - loss: 9.7275 - root_mean_squared_error: 3.1189
# Epoch 196/200
# 13/13 [==============================] - 0s 2ms/step - loss: 9.7005 - root_mean_squared_error: 3.1146
# Epoch 197/200
# 13/13 [==============================] - 0s 2ms/step - loss: 9.6666 - root_mean_squared_error: 3.1091
# Epoch 198/200
# 13/13 [==============================] - 0s 2ms/step - loss: 9.6224 - root_mean_squared_error: 3.1020
# Epoch 199/200
# 13/13 [==============================] - 0s 2ms/step - loss: 9.6188 - root_mean_squared_error: 3.1014
# Epoch 200/200
# 13/13 [==============================] - 0s 2ms/step - loss: 9.5840 - root_mean_squared_error: 3.0958
# 4/4 [==============================] - 0s 4ms/step - loss: 9.6876 - root_mean_squared_error: 3.1125

# %%
# access the pen-ultimate laters
basis_func = Model(inputs=model.input,
                   outputs=model.get_layer('layer_2').output)

# %%
# obtain output of the second hidden layer by calling predict method
layer_2_output = basis_func.predict(X_test)

# %%
layer_2_output = basis_func.predict(X_test)

# %%
layer_2_output
# Out:
# array([[6.67803884e-01, 4.85449028e+00, 0.00000000e+00, 6.59669971e+00,
#         0.00000000e+00, 0.00000000e+00, 4.74888086e+00, 7.09521484e+00],
#        [4.93824100e+00, 2.08727241e+00, 0.00000000e+00, 1.10894699e+01,
#         3.50147414e+00, 0.00000000e+00, 5.50131464e+00, 8.15977764e+00],
#        [0.00000000e+00, 1.34282188e+01, 0.00000000e+00, 1.14597454e+01,
#         0.00000000e+00, 0.00000000e+00, 1.52780943e+01, 1.26173525e+01],
#        [0.00000000e+00, 1.08129768e+01, 0.00000000e+00, 1.09407024e+01,
#         0.00000000e+00, 0.00000000e+00, 1.20765619e+01, 1.09764414e+01],
#        [2.44981170e-01, 5.23128128e+00, 0.00000000e+00, 1.14304829e+01,
#         6.48803830e-01, 0.00000000e+00, 9.23081589e+00, 9.65928936e+00],
#         3.90584159e+00, 0.00000000e+00, 4.15574741e+00, 6.88448477e+00],
#        [0.00000000e+00, 1.24120979e+01, 0.00000000e+00, 1.31106262e+01,
#         0.00000000e+00, 0.00000000e+00, 1.42461290e+01, 1.33386984e+01],
#        [0.00000000e+00, 9.73226357e+00, 0.00000000e+00, 1.19395657e+01,
#         0.00000000e+00, 0.00000000e+00, 1.30199680e+01, 1.14111338e+01],
#        [0.00000000e+00, 7.93812418e+00, 0.00000000e+00, 8.13387299e+00,
#         0.00000000e+00, 0.00000000e+00, 7.76929283e+00, 7.25320196e+00],
#        [0.00000000e+00, 6.26712990e+00, 0.00000000e+00, 6.07500029e+00,
#         0.00000000e+00, 0.00000000e+00, 6.13992453e+00, 5.85586309e+00],
#        [3.41293097e+00, 3.27978897e+00, 0.00000000e+00, 1.12482643e+01,
#         2.56641483e+00, 0.00000000e+00, 6.91875029e+00, 8.56469440e+00],
#        [3.99700069e+00, 3.49675870e+00, 0.00000000e+00, 1.03310280e+01,
#         2.13237381e+00, 0.00000000e+00, 6.14089918e+00, 9.16247272e+00],
#        [7.66413641e+00, 4.32735777e+00, 0.00000000e+00, 1.60726871e+01,
#         3.57601905e+00, 0.00000000e+00, 7.61120224e+00, 1.23156137e+01],
#        [0.00000000e+00, 1.23877220e+01, 0.00000000e+00, 1.14291248e+01,
#         0.00000000e+00, 0.00000000e+00, 1.26400604e+01, 1.20599508e+01],
#        [4.24124527e+00, 1.97120857e+00, 0.00000000e+00, 1.03347359e+01,
#         3.28069282e+00, 0.00000000e+00, 5.28253222e+00, 7.47670126e+00]],
#       dtype=float32)

# %% [markdown]
# Build Bayesian linear regressor

# %%
class BayesianLastLayer():

  def __init__(self,
                model,
                basis_layer,
                n_samples=1e4,
                n_burnin=5e3,
                step_size=1e-4,
                n_leapfrog=10,
                adaptive=False):
      # Setting up our model
      self.model = model
      self.basis_layer = basis_layer
      self.initialize_basis_function()
      # HMC Settings
      # number of hmc samples
      self.n_samples = int(n_samples)
      # number of burn-in steps
      self.n_burnin = int(n_burnin)
      # HMC step size
      self.step_size = step_size
      # HMC leapfrog steps
      self.n_leapfrog = n_leapfrog
      # whether to be adaptive or not
      self.adaptive = adaptive

  # define helper function for using the neural network as a basis function
  def initialize_basis_function(self):
      self.basis_func = Model(inputs=self.model.input,
                              outputs=self.model.get_layer(self.basis_layer).output)

  # define helper function to easily get predictions from helper function
  def get_basis(self, X):
      return self.basis_func.predict(X)

  # define fuction for fitting the Bayesian linear regressor on data
  def fit(self, X, y):
      X = tf.convert_to_tensor(self.get_basis(X), dtype=dtype)
      y = tf.convert_to_tensor(y, dtype=dtype)
      y = tf.reshape(y, (-1, 1))
      D = X.shape[1]

      # Define our joint distribution
      distribution = tfp.distributions.JointDistributionNamedAutoBatched(
          dict(
              sigma=tfp.distributions.HalfNormal(scale=tf.ones([1])),
              alpha=tfp.distributions.Normal(
                  loc=tf.zeros([1]),
                  scale=tf.ones([1]),
              ),
              beta=tfp.distributions.Normal(
                  loc=tf.zeros([D,1]),
                  scale=tf.ones([D,1]),
              ),
              y=lambda beta, alpha, sigma:
                  tfp.distributions.Normal(
                      loc=tf.linalg.matmul(X, beta) + alpha,
                      scale=sigma
                  )
              )
          )

      # Define the log probability function
      def target_log_prob_fn(beta, alpha, sigma):
          return distribution.log_prob(beta=beta, alpha=alpha, sigma=sigma, y=y)

      # Define the HMC kernel we'll be using for sampling
      hmc_kernel  = tfp.mcmc.HamiltonianMonteCarlo(
        target_log_prob_fn=target_log_prob_fn,
        step_size=self.step_size,
        num_leapfrog_steps=self.n_leapfrog
      )

      # We can use adaptive HMC to automatically adjust the kernel step size
      if self.adaptive:
          adaptive_hmc = tfp.mcmc.SimpleStepSizeAdaptation(
            inner_kernel = hmc_kernel,
            num_adaptation_steps=int(self.n_burnin * 0.8)
          )

      # If we define a function, we can extend this to multiple chains.
      @tf.function
      def run_chain():
          states, kernel_results = tfp.mcmc.sample_chain(
                num_results=self.n_samples,
                num_burnin_steps=self.n_burnin,
                current_state=[
                    tf.zeros((X.shape[1],1), name='init_model_coeffs'),
                    tf.zeros((1), name='init_bias'),
                    tf.ones((1), name='init_noise'),
                ],
                kernel=hmc_kernel
              )
          return states, kernel_results

      print(f'Running HMC with {self.n_samples} samples.')
      states, kernel_results = run_chain()

      print('Completed HMC sampling.')
      coeffs, bias, noise_std = states
      accepted_samples = kernel_results.is_accepted[self.n_burnin:]
      acceptance_rate = 100*np.mean(accepted_samples)
      # Print the acceptance rate - if this is low, we need to check our
      # HMC parameters
      print('Acceptance rate: %0.1f%%' % (acceptance_rate))

      # Obtain the post-burnin samples
      self.model_coeffs = coeffs[self.n_burnin:,:,0]
      self.bias = bias[self.n_burnin:]
      self.noise_std = noise_std[self.n_burnin:]

  def get_pred_dist(self, X):
      predictions = (tf.matmul(X, tf.transpose(self.model_coeffs)) +
                    self.bias[:,0])
      noise = (self.noise_std[:,0] *
              tf.random.normal([self.noise_std.shape[0]]))
      return predictions + noise

  def predict(self, X):
      X = tf.convert_to_tensor(self.get_basis(X), dtype=dtype)
      pred_dist = np.zeros((X.shape[0], self.model_coeffs.shape[0]))
      X = tf.reshape(X, (-1, 1, X.shape[1]))
      for i in range(X.shape[0]):
        pred_dist[i,:] = self.get_pred_dist(X[i,:])

      y_pred = np.mean(pred_dist, axis=1)
      y_std = np.std(pred_dist, axis=1)
      return y_pred, y_std

# %%
# instatiate last layer model
bll = BayesianLastLayer(model, 'layer_2')
# fit model on training data
bll.fit(X_train, y_train)
# perform inference
y_pred, y_std = bll.predict(X_test)
# Out:
# Running HMC with 10000 samples.
# /usr/local/lib/python3.7/dist-packages/tensorflow_probability/python/mcmc/sample.py:339: UserWarning: Tracing all kernel results by default is deprecated. Set the `trace_fn` argument to None (the future default value) or an explicit callback that traces the values you are interested in.
#   warnings.warn('Tracing all kernel results by default is deprecated. Set '
# Completed HMC sampling.
# Acceptance rate: 100.0%
